# %% [markdown]
# <b>Download the dataset from this link.</b>
# <br> https://drive.google.com/file/d/1qpPwOdKChwMCDbL8j6JO2KzHCWcWftRF/view?usp=sharing

# %% [markdown]
# ## SMS Spam Collection Data Set

# %% [markdown]
# <b>Abstract:</b> The SMS Spam Collection is a public set of SMS labeled messages that have been collected for mobile phone spam research.
#
# <b>Data Set Information:</b>
#
# This corpus has been collected from free or free for research sources at the Internet:
#
# A collection of 425 SMS spam messages was manually extracted from the Grumbletext Web site. This is a UK forum in which cell phone users make public claims about SMS spam messages, most of them without reporting the very spam message received. The identification of the text of spam messages in the claims is a very hard and time-consuming task, and it involved carefully scanning hundreds of web pages.
#
# A subset of 3,375 SMS randomly chosen ham messages of the NUS SMS Corpus (NSC), which is a dataset of about 10,000 legitimate messages collected for research at the Department of Computer Science at the National University of Singapore. The messages largely originate from Singaporeans and mostly from students attending the University. These messages were collected from volunteers who were made aware that their contributions were going to be made publicly available.
#
# A list of 450 SMS ham messages collected from Caroline Tag's PhD Thesis.
#
# Finally, we have incorporated the SMS Spam Corpus v.0.1 Big. It has 1,002 SMS ham messages and 322 spam messages. This corpus has been used in the following academic researches:
#
# [1] GÃ³mez Hidalgo, J.M., Cajigas Bringas, G., Puertas Sanz, E., Carrero GarcÃ­a, F. Content Based SMS Spam Filtering. Proceedings of the 2006 ACM Symposium on Document Engineering (ACM DOCENG'06), Amsterdam, The Netherlands, 10-13, 2006.
#
# [2] Cormack, G. V., GÃ³mez Hidalgo, J. M., and Puertas SÃ¡nz, E. Feature engineering for mobile (SMS) spam filtering. Proceedings of the 30th Annual international ACM Conference on Research and Development in information Retrieval (ACM SIGIR'07), New York, NY, 871-872, 2007.
#
# [3] Cormack, G. V., GÃ³mez Hidalgo, J. M., and Puertas SÃ¡nz, E. Spam filtering for short messages. Proceedings of the 16th ACM Conference on Information and Knowledge Management (ACM CIKM'07). Lisbon, Portugal, 313-320, 2007.
# <br>
# <br>
# <b>
# Attribute Information:
# </b>
#
# The collection is composed by just one text file, where each line has the correct class followed by the raw message. We offer some examples bellow:
#
# ham What you doing?how are you?
# ham Ok lar... Joking wif u oni...
# ham dun say so early hor... U c already then say...
# ham MY NO. IN LUTON 0125698789 RING ME IF UR AROUND! H*
# ham Siva is in hostel aha:-.
# ham Cos i was out shopping wif darren jus now n i called him 2 ask wat present he wan lor. Then he started guessing who i was wif n he finally guessed darren lor.
# spam FreeMsg: Txt: CALL to No: 86888 & claim your reward of 3 hours talk time to use from your phone now! ubscribe6GBP/ mnth inc 3hrs 16 stop?txtStop
# spam Sunshine Quiz! Win a super Sony DVD recorder if you canname the capital of Australia? Text MQUIZ to 82277. B
# spam URGENT! Your Mobile No 07808726822 was awarded a L2,000 Bonus Caller Prize on 02/09/03! This is our 2nd attempt to contact YOU! Call 0871-872-9758 BOX95QU
#
# Note: the messages are not chronologically sorted.

# %% [markdown]
# ### 1. Loading the data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
tweet_df= pd.read_csv("SMSSpamCollection.csv", engine='python')

# %%
tweet_df.head()
# Out:
#     sms                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
tweet_df.columns
# Out:
# Index(['sms', 'message'], dtype='object')

# %% [markdown]
# ### 2. EDA

# %%
tweet_df.head()
# Out:
#     sms                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
tweet_df.shape
# Out:
# (5574, 2)

# %%
tweet_df['sms'].value_counts()
# Out:
# ham     4827
# spam     747
# Name: sms, dtype: int64

# %%
sns.countplot(x='sms', data=tweet_df)

# %% [markdown]
# #### Word Cloud for spam SMS

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
df = tweet_df.loc[tweet_df['sms']=='spam', :]

# %%
df.head()
# Out:
#      sms                                            message
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 5   spam  FreeMsg Hey there darling it's been 3 week's n...
# 8   spam  WINNER!! As a valued network customer you have...
# 9   spam  Had your mobile 11 months or more? U R entitle...
# 11  spam  SIX chances to win CASH! From 100 to 20,000 po...

# %%
df['sms'].value_counts()
# Out:
# spam    747
# Name: sms, dtype: int64

# %%
words = ' '.join(df['message'])
print(words)
# Out:
# Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's FreeMsg Hey there darling it's been 3 week's now and no word back! I'd like some fun you up for it still? Tb ok! XxX std chgs to send, ?œ1.50 to rcv WINNER!! As a valued network customer you have been selected to receivea ?œ900 prize reward! To claim call 09061701461. Claim code KL341. Valid 12 hours only. Had your mobile 11 months or more? U R entitled to Update to the latest colour mobiles with camera for Free! Call The Mobile Update Co FREE on 08002986030 SIX chances to win CASH! From 100 to 20,000 pounds txt> CSH11 and send to 87575. Cost 150p/day, 6days, 16+ TsandCs apply Reply HL 4 info URGENT! You have won a 1 week FREE membership in our ?œ100,000 Prize Jackpot! Txt the word: CLAIM to No: 81010 T&C www.dbuk.net LCCLTD POBOX 4403LDNW1A7RW18 XXXMobileMovieClub: To use your credit, click the WAP link in the next txt message or click here>> http://wap. xxxmobilemovieclub.com?n=QJKGIGHJJGCBL England v Macedonia - dont miss the goals/team news. Txt ur national team to 87077 eg ENGLAND to 87077 Try:WALES, SCOTLAND 4txt/?§1.20 POBOXox36504W45WQ 16+ Thanks for your subscription to Ringtone UK your mobile will be charged ?œ5/month Please confirm by replying YES or NO. If you reply NO you will not be charged 07732584351 - Rodger Burns - MSG = We tried to call you re your reply to our sms for a free nokia mobile + free camcorder. Please call now 08000930705 for delivery tomorrow SMS. ac Sptv: The New Jersey Devils and the Detroit Red Wings play Ice Hockey. Correct or Incorrect? End? Reply END SPTV Congrats! 1 year special cinema pass for 2 is yours. call 09061209465 now! C Suprman V, Matrix3, StarWars3, etc all 4 FREE! bx420-ip4-5we. 150pm. Dont miss out!  As a valued customer, I am pleased to advise you that following recent review of your Mob No. you are awarded with a ?œ1500 Bonus Prize, call 09066364589 Urgent UR awarded a complimentary trip to EuroDisinc Trav, Aco&Entry41 Or ?œ1000. To claim txt DIS to 87121 18+6*?œ1.50(moreFrmMob. ShrAcomOrSglSuplt)10, LS1 3AJ Did you hear about the new "Divorce Barbie"? It comes with all of Ken's stuff! Please call our customer service representative on 0800 169 6031 between 10am-9pm as you have WON a guaranteed ?œ1000 cash or ?œ5000 prize! Your free ringtone is waiting to be collected. Simply text the password "MIX" to 85069 to verify. Get Usher and Britney. FML, PO Box 5249, MK17 92H. 450Ppw 16 GENT! We are trying to contact you. Last weekends draw shows that you won a ?œ1000 prize GUARANTEED. Call 09064012160. Claim Code K52. Valid 12hrs only. 150ppm You are a winner U have been specially selected 2 receive ?œ1000 or a 4* holiday (flights inc) speak to a live operator 2 claim 0871277810910p/min (18+)  PRIVATE! Your 2004 Account Statement for 07742676969 shows 786 unredeemed Bonus Points. To claim call 08719180248 Identifier Code: 45239 Expires URGENT! Your Mobile No. was awarded ?œ2000 Bonus Caller Prize on 5/9/03 This is our final try to contact U! Call from Landline 09064019788 BOX42WR29C, 150PPM Todays Voda numbers ending 7548 are selected to receive a $350 award. If you have a match please call 08712300220 quoting claim code 4041 standard rates app Sunshine Quiz Wkly Q! Win a top Sony DVD player if u know which country the Algarve is in? Txt ansr to 82277. ?œ1.50 SP:Tyrone Want 2 get laid tonight? Want real Dogging locations sent direct 2 ur mob? Join the UK's largest Dogging Network bt Txting GRAVEL to 69888! Nt. ec2a. 31p.msg@150p You'll not rcv any more msgs from the chat svc. For FREE Hardcore services text GO to: 69988 If u get nothing u must Age Verify with yr network & try again FreeMsg Why haven't you replied to my text? I'm Randy, sexy, female and live local. Luv to hear from u. Netcollex Ltd 08700621170150p per msg reply Stop to end Customer service annoncement. You have a New Years delivery waiting for you. Please call 0 ...

# %%
cleaned_word = " ".join([word for word in words.split()])

# %%
wordcloud = WordCloud(stopwords=STOPWORDS,
                      background_color='black',
                      width=1600,
                      height=800
                     ).generate(cleaned_word)

# %%
plt.figure(1,figsize=(30,20))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# ### 3. Data Preprocessing

# %%
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
# initialise the inbuilt Stemmer
stemmer = PorterStemmer()

# %%
# We can also use Lemmatizer instead of Stemmer
lemmatizer = WordNetLemmatizer()

# %%
# initializing the lists
clean_tweet_lst = []
tweet_len_lst = []

# %%
def preprocess(raw_tweet, flag):
    # Removing special characters and digits
    letters_only = re.sub("[^a-zA-Z]", " ",raw_tweet)
    letters_only = letters_only.lower()

    # tokenize into words
    words = letters_only.split()
    
    # remove stop words                
    words = [w for w in words if not w in stopwords.words("english")]
    
    # Stemming/Lemmatization
    if(flag == 'stem'):
        words = [stemmer.stem(word) for word in words]
    else:
        words = [lemmatizer.lemmatize(word) for word in words]
    
    clean_tweet_lst.append(" ".join(words))
    tweet_len_lst.append(len(words))

# %%
tweet_df['sms_spam']=tweet_df['sms'].apply(lambda x: 0 if x=='spam' else 1)

# %%
clean_tweet_lst = []
tweet_len_lst = []

tweet_df['message'].apply(lambda x: preprocess(x, 'stem'))

tweet_df['clean_tweet_stem'] = clean_tweet_lst

tweet_df['tweet_length_stem'] = tweet_len_lst

# %%
clean_tweet_lst = []
tweet_len_lst = []

tweet_df['message'].apply(lambda x: preprocess(x, 'lemma'))

tweet_df['clean_tweet_lema'] = clean_tweet_lst

tweet_df['tweet_length_lema'] = tweet_len_lst

# %%
tweet_df.head()
# Out:
#     sms                                            message  sms_spam  \
# 0   ham  Go until jurong point, crazy.. Available only ...         1
# 1   ham                      Ok lar... Joking wif u oni...         1
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...         0
# 3   ham  U dun say so early hor... U c already then say...         1
# 4   ham  Nah I don't think he goes to usf, he lives aro...         1
#
#                                     clean_tweet_stem  tweet_length_stem  \
# 0  go jurong point crazi avail bugi n great world...                 16
# 1                              ok lar joke wif u oni                  6
# 2  free entri wkli comp win fa cup final tkt st m...                 21
# 3                u dun say earli hor u c alreadi say                  9
# 4               nah think goe usf live around though                  7
#
#                                     clean_tweet_lema  tweet_length_lema
# 0  go jurong point crazy available bugis n great ...                 16
# 1                            ok lar joking wif u oni                  6
# 2  free entry wkly comp win fa cup final tkts st ...                 21
# 3                u dun say early hor u c already say                  9
# 4                nah think go usf life around though                  7

# %% [markdown]
# ### 4. Data Preparation

# %%
# splitting into test and train

from sklearn.model_selection  import train_test_split
train, test = train_test_split(tweet_df,test_size=0.2,random_state=42)

# %%
train_clean_tweet=[]
for tweet in train['clean_tweet_stem']:
    train_clean_tweet.append(tweet)

test_clean_tweet=[]
for tweet in test['clean_tweet_stem']:
    test_clean_tweet.append(tweet)

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(analyzer = "word")
train_features = vectorizer.fit_transform(train_clean_tweet)
test_features = vectorizer.transform(test_clean_tweet)

# %%
vectorizer.vocabulary_
# Out:
# {'free': 1767,
#  'day': 1128,
#  'sexi': 4219,
#  'st': 4530,
#  'georg': 1875,
#  'pic': 3567,
#  'jordan': 2469,
#  'txt': 5053,
#  'dont': 1306,
#  'miss': 2999,
#  'everi': 1513,
#  'wk': 5424,
#  'sauci': 4126,
#  'celeb': 763,
#  'pocketbab': 3624,
#  'co': 906,
#  'uk': 5075,
#  'armand': 267,
#  'say': 4131,
#  'get': 1879,
#  'ass': 297,
#  'epsilon': 1477,
#  'lol': 2733,
#  'hot': 2190,
#  'air': 109,
#  'balloon': 387,
#  'know': 2564,
#  'wot': 5466,
#  'peopl': 3516,
#  'wear': 5315,
#  'shirt': 4262,
#  'jumper': 2487,
#  'hat': 2072,
#  'belt': 465,
#  'cribb': 1050,
#  'good': 1938,
#  'morn': 3062,
#  'love': 2769,
#  'go': 1920,
#  'sleep': 4357,
#  'wish': 5411,
#  'great': 1987,
#  'full': 1812,
#  'feel': 1626,
#  'better': 478,
#  'opportun': 3368,
#  'last': 2615,
#  'thought': 4865,
#  'babe': 365,
#  'kiss': 2555,
#  'ur': 5143,
#  'bahama': 377,
#  'callfreefon': 701,
#  'speak': 4473,
#  'live': 2709,
#  'oper': 3364,
#  'claim': 871,
#  'either': 1423,
#  'cruis': 1060,
#  'cash': 745,
#  'opt': 3371,
#  'sorri': 4450,
#  'abl': 15,
#  'see': 4177,
#  'call': 695,
#  'later': 2618,
#  'parti': 3471,
#  'alex': 129,
#  'nichol': 3214,
#  'crazi': 1039,
#  'ar': 251,
#  'marri': 2878,
#  'like': 2682,
#  'gd': 1858,
#  'look': 2744,
#  'guy': 2023,
#  'fren': 1776,
#  'korean': 2574,
#  'leona': 2658,
#  'fave': 1613,
#  'dun': 1365,
#  'thk': 4853,
#  'aft': 88,
#  'think': 4847,
#  'mayb': 2905,
#  'prob': 3744,
#  'somewher': 4431,
#  'fredericksburg': 1766,
#  'issu': 2390,
#  'right': 4012,
#  'ill': 2275,
#  'fix': 1683,
#  'tomorrow': 4943,
#  'wah': 5262,
#  'lucki': 2793,
#  'man': 2851,
#  'save': 4129,
#  'money': 3048,
#  'hee': 2106,
#  'beneath': 468,
#  'pale': 3442,
#  'moon': 3059,
#  'light': 2678,
#  'someon': 4423,
#  'dream': 1333,
#  'come': 932,
#  'true': 5019,
#  'goodnit': 1945,
#  'amp': 173,
#  'sweet': 4700,
#  'ye': 5539,
#  'appt': 244,
#  'tmr': 4915,
#  'timin': 4897,
#  'still': 4572,
#  'da': 1099,
#  'wat': 5295,
#  'got': 1955,
#  'lesson': 2662,
#  'ta': 4721,
#  'job': 2456,
#  'avail': 336,
#  'let': 2663,
#  'pleas': 3603,
#  'realli': 3892,
#  'need': 3181,
#  'start': 4545,
#  'work': 5455,
#  'refus': 3928,
#  'loan': 2720,
#  'secur': 4175,
#  'unsecur': 5125,
#  'credit': 1046,
#  'text': 4807,
#  'back': 369,
#  'help': 2116,
#  'secret': 4172,
#  'admir': 63,
#  'reveal': 3997,
#  'special': 4474,
#  'repli': 3963,
#  'stop': 4581,
#  'per': 3517,
#  'msg': 3090,
#  'recd': 3901,
#  'cust': 1087,
#  'care': 732,
#  'ugh': 5070,
#  'fuck': 1804,
#  'resub': 3989,
#  'eve': 1508,
#  'anyth': 212,
#  'lor': 2752,
#  'congratul': 972,
#  'thank': 4820,
#  'friend': 1785,
#  'xma': 5508,
#  'prize': 3741,
#  'easi': 1383,
#  'minut': 2992,
#  'bt': 641,
#  'nation': 3160,
#  'rate': 3867,
#  'wil': 5390,
#  'reach': 3881,
#  'chuckin': 860,
#  'red': 3917,
#  'green': 1990,
#  'black': 516,
#  'trainner': 4989,
#  'carryin': 742,
#  'bac': 368,
#  'train': 4988,
#  'ha': 2028,
#  'us': 5155,
#  'thing': 4846,
#  'tv': 5043,
#  'watch': 5296,
#  'tonight': 4950,
#  'alreadi': 148,
#  'haf': 2032,
#  'smth': 4396,
#  'mind': 2979,
#  'chanc': 783,
#  'search': 4166,
#  'hard': 2063,
#  'tri': 5007,
#  'shop': 4274,
#  'till': 4894,
#  'drop': 1345,
#  'travel': 4998,
#  'voucher': 5252,
#  'ntt': 3281,
#  'po': 3618,
#  'box': 581,
#  'cr': 1030,
#  'fixedlin': 1684,
#  'cost': 1007,
#  'ppm': 3677,
#  'mobil': 3029,
#  'vari': 5186,
#  'yup': 5583,
#  'studi': 4615,
#  'surf': 4679,
#  'lazi': 2628,
#  'mode': 3036,
#  'today': 4925,
#  'bitch': 512,
#  'act': 46,
#  'interest': 2356,
#  'buy': 676,
#  'someth': 4426,
#  'els': 1434,
#  'next': 3209,
#  'week': 5329,
#  'gave': 1851,
#  'heard': 2098,
#  'abt': 20,
#  'tat': 4753,
#  'oh': 3328,
#  'gei': 1864,
#  'happend': 2059,
#  'tron': 5014,
#  'dl': 1277,
#  'puriti': 3805,
#  'friendship': 1786,
#  'two': 5052,
#  'smile': 4388,
#  'read': 3884,
#  'forward': 1748,
#  'messag': 2952,
#  'name': 3146,
#  'gud': 2012,
#  'evng': 1527,
#  'leav': 2644,
#  'yet': 5553,
#  'ok': 3332,
#  'elsewher': 1435,
#  'eat': 1390,
#  'camera': 708,
#  'quit': 3832,
#  'mega': 2929,
#  'pixel': 3587,
#  'optic': 3372,
#  'digit': 1235,
#  'doom': 1311,
#  'holiday': 2164,
#  'safe': 4084,
#  'hope': 2181,
#  'hav': 2076,
#  'journey': 2472,
#  'happi': 2061,
#  'new': 3201,
#  'year': 5541,
#  'coupl': 1019,
#  'decis': 1148,
#  'could': 1013,
#  'decid': 1146,
#  'life': 2673,
#  'would': 5469,
#  'much': 3103,
#  'simpler': 4319,
#  'less': 2660,
#  'magic': 2832,
#  'ya': 5524,
#  'cant': 720,
#  'display': 1267,
#  'intern': 2358,
#  'sub': 4624,
#  'gotta': 1962,
#  'extract': 1569,
#  'dice': 1219,
#  'art': 279,
#  'class': 876,
#  'thru': 4876,
#  'though': 4864,
#  'idea': 2259,
#  'time': 4895,
#  'well': 5342,
#  'weekend': 5331,
#  'mani': 2861,
#  'sinc': 4323,
#  'melodi': 2936,
#  'run': 4067,
#  'ttyl': 5031,
#  'yep': 5549,
#  'derek': 1189,
#  'hous': 2197,
#  'sunday': 4656,
#  'lt': 2786,
#  'mr': 3084,
#  'sheffield': 4248,
#  'wanna': 5283,
#  'play': 3598,
#  'game': 1835,
#  'okay': 3333,
#  'boss': 571,
#  'nanni': 3151,
#  'give': 1903,
#  'rais': 3846,
#  'one': 3351,
#  'senthil': 4202,
#  'group': 2000,
#  'compani': 943,
#  'apnt': 223,
#  'pm': 3616,
#  'friday': 1783,
#  'find': 1664,
#  'altern': 153,
#  'yr': 5575,
#  'term': 4797,
#  'im': 2278,
#  'suffer': 4640,
#  'fever': 1638,
#  'dysentri': 1376,
#  'offic': 3319,
#  'bill': 498,
#  'letter': 2664,
#  'expect': 1553,
#  'orang': 3379,
#  'may': 2904,
#  'send': 4194,
#  'haha': 2033,
#  'yeah': 5540,
#  'oz': 3430,
#  'kind': 2547,
#  'shitload': 4267,
#  'told': 4933,
#  'accentur': 27,
#  'confirm': 967,
#  'respons': 3984,
#  'date': 1123,
#  'servic': 4212,
#  'cal': 690,
#  'sk': 4343,
#  'ch': 775,
#  'aathi': 4,
#  'lot': 2758,
#  'gonna': 1936,
#  'death': 1141,
#  'note': 3262,
#  'rob': 4027,
#  'fault': 1611,
#  'aveng': 342,
#  'usual': 5165,
#  'iam': 2243,
#  'fine': 1665,
#  'total': 4972,
#  'disappoint': 1255,
#  'craziest': 1040,
#  'shit': 4263,
#  'anyon': 210,
#  'spare': 4469,
#  'room': 4039,
#  'top': 4960,
#  'head': 2088,
#  'said': 4086,
#  'matter': 2898,
#  'colleg': 927,
#  'atten': 319,
#  'super': 4665,
#  'nalla': 3144,
#  'everyth': 1519,
#  'dehydr': 1166,
#  'babi': 366,
#  'pictur': 3571,
#  'facebook': 1576,
#  'hey': 2127,
#  'breath': 603,
#  'neck': 3178,
#  'bud': 648,
#  'anyway': 217,
#  'half': 2041,
#  'track': 4984,
#  'usf': 5162,
#  'film': 1656,
#  'comput': 956,
#  'brah': 588,
#  'urgent': 5147,
#  'landlin': 2600,
#  'complimentari': 953,
#  'ibiza': 2246,
#  'await': 348,
#  'collect': 926,
#  'sae': 4082,
#  'cs': 1063,
#  'wp': 5473,
#  'normal': 3257,
#  'panic': 3447,
#  'tuesday': 5033,
#  'goodmorn': 1943,
#  'late': 2616,
#  'hr': 2208,
#  'rock': 4028,
#  'press': 3715,
#  'confer': 964,
#  'probabl': 3745,
#  'around': 272,
#  'mu': 3101,
#  'bugi': 655,
#  'oso': 3396,
#  'near': 3171,
#  'multimedia': 3110,
#  'mail': 2838,
#  'wait': 5269,
#  'machan': 2816,
#  'talk': 4737,
#  'amma': 167,
#  'take': 4733,
#  'turn': 5042,
#  'sit': 4334,
#  'hold': 2160,
#  'steer': 4561,
#  'heehe': 2107,
#  'funni': 1821,
#  'tho': 4861,
#  'nt': 3278,
#  'dai': 1104,
#  'gt': 2007,
#  'naal': 3137,
#  'eruku': 1487,
#  'antibiot': 206,
#  'use': 5159,
#  'chest': 821,
#  'abdomen': 7,
#  'gyna': 2027,
#  'infect': 2323,
#  'even': 1510,
#  'bone': 555,
#  'how': 2199,
#  'champ': 780,
#  'glasgow': 1907,
#  'dear': 1138,
#  'hero': 2123,
#  'qatar': 3815,
#  'tonit': 4951,
#  'apt': 248,
#  'pl': 3589,
#  'keep': 2525,
#  'touch': 4974,
#  'email': 1437,
#  'kerala': 2531,
#  'forgot': 1739,
#  'eh': 1418,
#  'bring': 614,
#  'what': 5360,
#  'plan': 3593,
#  'sat': 4119,
#  'never': 3198,
#  'answer': 199,
#  'deni': 1180,
#  'telugu': 4787,
#  'movi': 3079,
#  'pick': 3568,
#  'winner': 5404,
#  'valu': 5182,
#  'network': 3195,
#  'custom': 1089,
#  'select': 4183,
#  'receivea': 3904,
#  'reward': 4001,
#  'code': 915,
#  'kl': 2558,
#  'valid': 5181,
#  'hour': 2195,
#  'number': 3287,
#  'neft': 3183,
#  'transact': 4991,
#  'refer': 3922,
#  'rs': 4051,
#  'decim': 1147,
#  'beneficiari': 469,
#  'account': 37,
#  'dollar': 1301,
#  'hi': 2130,
#  'mrw': 3088,
#  'ninish': 3227,
#  'address': 58,
#  'icki': 2254,
#  'american': 163,
#  'freek': 1771,
#  'wont': 5447,
#  'callin': 702,
#  'bad': 372,
#  'jen': 2437,
#  'pa': 3431,
#  'self': 4184,
#  'knacker': 2559,
#  'came': 707,
#  'home': 2167,
#  'went': 5347,
#  'lark': 2613,
#  'gram': 1973,
#  'eighth': 1420,
#  'smarter': 4383,
#  'almost': 144,
#  'whole': 5375,
#  'second': 4170,
#  'ola': 3339,
#  'direct': 1248,
#  'link': 2695,
#  'car': 728,
#  'bid': 494,
#  'onlin': 3354,
#  'arrang': 275,
#  'ship': 4261,
#  'cut': 1091,
#  'partnership': 3476,
#  'invest': 2367,
#  'rest': 3985,
#  'wud': 5492,
#  'reliant': 3942,
#  'soon': 4442,
#  'dnt': 1281,
#  'worri': 5460,
#  'wet': 5358,
#  'men': 2941,
#  'shorter': 4282,
#  'ladi': 2590,
#  'gaze': 1855,
#  'eye': 1571,
#  'gnarl': 1917,
#  'barkley': 403,
#  'rington': 4017,
#  'fli': 1698,
#  'monkey': 3050,
#  'certainli': 773,
#  'mine': 2981,
#  'settl': 4214,
#  'school': 4142,
#  'wishin': 5412,
#  'gr': 1969,
#  'shoot': 4273,
#  'doc': 1284,
#  'make': 2843,
#  'appoint': 239,
#  'voda': 5241,
#  'end': 1448,
#  'receiv': 3903,
#  'award': 350,
#  'hava': 2077,
#  'match': 2890,
#  'quot': 3836,
#  'standard': 4540,
#  'app': 228,
#  'listen': 2703,
#  'twice': 5047,
#  'rip': 4020,
#  'uteru': 5167,
#  'wow': 5472,
#  'healthi': 2095,
#  'old': 3343,
#  'airport': 110,
#  'rd': 3879,
#  'bath': 413,
#  'dog': 1293,
#  'sure': 4678,
#  'drive': 1340,
#  'destin': 1200,
#  'ju': 2479,
#  'ate': 308,
#  'honey': 2171,
#  'hdd': 2086,
#  'case': 744,
#  'meet': 2926,
#  'librari': 2669,
#  'privat': 3738,
#  'statement': 4550,
#  'nice': 3213,
#  'readi': 3886,
#  'thursday': 4880,
#  'believ': 457,
#  'want': 5285,
#  'beauti': 433,
#  'abta': 21,
#  'spanish': 4468,
#  'ez': 1572,
#  'hack': 2031,
#  'chat': 798,
#  'backdoor': 370,
#  'entri': 1468,
#  'fraction': 1757,
#  'neo': 3189,
#  'subscrib': 4628,
#  'dp': 1324,
#  'bcm': 426,
#  'ldn': 2633,
#  'wc': 5312,
#  'xx': 5513,
#  'show': 4289,
#  'unredeem': 5124,
#  'bonu': 557,
#  'point': 3628,
#  'identifi': 2262,
#  'expir': 1558,
#  'depend': 1185,
#  'alright': 149,
#  'advic': 74,
#  'enjoy': 1457,
#  'night': 3221,
#  'lov': 2767,
#  'nevr': 3200,
#  'unrecogn': 5123,
#  'somon': 4434,
#  'often': 3325,
#  'mistak': 3007,
#  'definitli': 1163,
#  'undrstnd': 5099,
#  'yay': 5537,
#  'final': 1660,
#  'cinema': 864,
#  'trip': 5009,
#  'urself': 5154,
#  'present': 3713,
#  'pattern': 3489,
#  'emerg': 1441,
#  'tell': 4783,
#  'smoke': 4391,
#  'weed': 5328,
#  'fiend': 1646,
#  'imped': 2290,
#  'hesit': 2125,
#  'girl': 1898,
#  'happen': 2058,
#  'alian': 135,
#  'imposs': 2294,
#  'argu': 262,
#  'alway': 157,
#  'treat': 5002,
#  'releas': 3941,
#  'remind': 3951,
#  'necessari': 3176,
#  'sunshin': 4662,
#  'quiz': 3834,
#  'wkli': 5428,
#  'win': 5396,
#  'soni': 4439,
#  'dvd': 1373,
#  'player': 3599,
#  'countri': 1018,
#  'algarv': 131,
#  'ansr': 198,
#  'sp': 4463,
#  'tyron': 5064,
#  'bother': 574,
#  'trust': 5023,
#  'bloomberg': 536,
#  'center': 767,
#  'appli': 237,
#  'futur': 1822,
#  'http': 2212,
#  'career': 734,
#  'com': 930,
#  'worth': 5463,
#  'discount': 1260,
#  'savamob': 4128,
#  'member': 2938,
#  'offer': 3318,
#  'pobox': 3619,
#  'uz': 5176,
#  'grr': 2004,
#  'mom': 3043,
#  'forev': 1734,
#  'prescript': 3711,
#  'pharmaci': 3549,
#  'away': 351,
#  'batteri': 416,
#  'low': 2777,
#  'rose': 4041,
#  'water': 5300,
#  'season': 4167,
#  'chang': 784,
#  'poet': 3627,
#  'imagin': 2280,
#  'phone': 3558,
#  'sm': 4377,
#  'frndship': 1790,
#  'latest': 2619,
#  'scroung': 4158,
#  'ammo': 168,
#  'ak': 118,
#  'part': 3470,
#  'check': 805,
#  'iq': 2378,
#  'sipix': 4330,
#  'fromm': 1796,
#  'deliveri': 1174,
#  'within': 5418,
#  'fact': 1578,
#  'ask': 291,
#  'ago': 98,
#  'nowaday': 3274,
#  'notixiqu': 3268,
#  'laxinorf': 2626,
#  'bambl': 389,
#  'entrop': 1469,
#  'ever': 1512,
#  'oblising': 3305,
#  'book': 560,
#  'masteriast': 2888,
#  'amplikat': 174,
#  'fidalf': 1643,
#  'champlaxig': 781,
#  'atroci': 315,
#  'wotz': 5467,
#  'opinion': 3365,
#  'junna': 2490,
#  'pin': 3580,
#  'favorit': 1615,
#  'oyster': 3429,
#  'sashimi': 4118,
#  'lar': 2611,
#  'stomach': 4576,
#  'rumbl': 4064,
#  'appl': 234,
#  'pair': 3441,
#  'malarki': 2847,
#  'import': 2291,
#  'hrishi': 2209,
#  'boo': 558,
#  'suppos': 4674,
#  'arr': 274,
#  'birthday': 509,
#  'oscar': 3395,
#  'bday': 429,
#  'real': 3887,
#  'april': 246,
#  'oooh': 3359,
#  'bed': 440,
#  'ridden': 4010,
#  'ey': 1570,
#  'onion': 3353,
#  'roast': 4026,
#  'anna': 189,
#  'nagar': 3139,
#  'afternoon': 90,
#  'bu': 645,
#  'coz': 1027,
#  'sort': 4452,
#  'stuff': 4619,
#  'bit': 511,
#  'longer': 2741,
#  'crowd': 1056,
#  'cardiff': 730,
#  'dave': 1126,
#  'notic': 3265,
#  'tenerif': 4794,
#  'tc': 4764,
#  'cw': 1095,
#  'wx': 5499,
#  'neva': 3196,
#  'grumbl': 2005,
#  'sad': 4081,
#  'lunch': 2797,
#  'meetin': 2927,
#  'hear': 2097,
#  'fr': 1756,
#  'lei': 2652,
#  'aiyo': 115,
#  'meh': 2930,
#  'small': 4379,
#  'macha': 2815,
#  'upset': 5139,
#  'assum': 302,
#  'mindset': 2980,
#  'wonder': 5446,
#  'begin': 452,
#  'anytim': 216,
#  'eaten': 1391,
#  'wan': 5281,
#  'immedi': 2286,
#  'first': 1676,
#  'song': 4438,
#  'stuck': 4611,
#  'reason': 3895,
#  'til': 4893,
#  'food': 1724,
#  'prefer': 3701,
#  'pap': 3454,
#  'slowli': 4374,
#  'load': 2719,
#  'sugar': 4644,
#  'squeeeeez': 4523,
#  'christma': 857,
#  'hug': 2215,
#  'lik': 2681,
#  'frndshp': 1791,
#  'den': 1178,
#  'cute': 1092,
#  'luvd': 2801,
#  'none': 3248,
#  'hate': 2073,
#  'moment': 3044,
#  'faith': 1585,
#  'luv': 2800,
#  'dude': 1359,
#  'afraid': 86,
#  'okey': 3336,
#  'dokey': 1299,
#  'guess': 2016,
#  'might': 2966,
#  'sir': 4331,
#  'velusami': 5200,
#  'birth': 507,
#  'bank': 396,
#  'facil': 1577,
#  'detail': 1202,
#  'lmao': 2716,
#  'workin': 5456,
#  'gee': 1861,
#  'thgt': 4843,
#  'nope': 3252,
#  'drivin': 1342,
#  'develop': 1206,
#  'photo': 3561,
#  'noth': 3263,
#  'di': 1215,
#  'wit': 5415,
#  'differ': 1230,
#  'replac': 3962,
#  'murali': 3118,
#  'contact': 981,
#  'attempt': 318,
#  'dept': 1188,
#  'min': 2976,
#  'accident': 31,
#  'delet': 1169,
#  'resend': 3971,
#  'hostel': 2188,
#  'absolut': 18,
#  'south': 4458,
#  'park': 3468,
#  'recent': 3905,
#  'hurt': 2232,
#  'teas': 4772,
#  'cri': 1049,
#  'die': 1226,
#  'plz': 3615,
#  'grave': 1982,
#  'stupid': 4620,
#  'bslvyl': 637,
#  'divorc': 1274,
#  'barbi': 400,
#  'ken': 2528,
#  'seen': 4180,
#  'holbi': 2159,
#  'rememb': 3948,
#  'satan': 4120,
#  'impost': 2295,
#  'pay': 3495,
#  'price': 3728,
#  'destini': 1201,
#  'pray': 3696,
#  'sindu': 4325,
#  'birla': 505,
#  'soft': 4413,
#  'didnt': 1224,
#  'holla': 2165,
#  'goodnight': 1944,
#  'thangam': 4819,
#  'ah': 100,
#  'confus': 970,
#  'doesnt': 1292,
#  'wrong': 5483,
#  'invit': 2369,
#  'anywher': 218,
#  'waqt': 5287,
#  'se': 4164,
#  'pehl': 3509,
#  'naseeb': 3155,
#  'zyada': 5596,
#  'kisi': 2554,
#  'ko': 2567,
#  'kuch': 2579,
#  'nahi': 3141,
#  'milta': 2975,
#  'zindgi': 5590,
#  'wo': 5436,
#  'jo': 2454,
#  'hum': 2221,
#  'socht': 4410,
#  'hai': 2035,
#  'ham': 2046,
#  'jeetey': 2436,
#  'spoon': 4508,
#  'tot': 4971,
#  'outsid': 3413,
#  'darren': 1118,
#  'cours': 1022,
#  'sim': 4316,
#  'lim': 2686,
#  'mp': 3081,
#  'wake': 5271,
#  'lindsay': 2689,
#  'sigh': 4307,
#  'bar': 399,
#  'ptbo': 3791,
#  'blue': 539,
#  'heron': 2124,
#  'lemm': 2654,
#  'swing': 4708,
#  'basic': 409,
#  'semest': 4190,
#  'somebodi': 4421,
#  'secretli': 4173,
#  'fanci': 1596,
#  'datebox': 1124,
#  'essexcm': 1497,
#  'xn': 5509,
#  'vodafon': 5242,
#  'th': 4817,
#  'gower': 1967,
#  'mate': 2891,
#  'wale': 5272,
#  'morrow': 3068,
#  'random': 3860,
#  'thanx': 4824,
#  'puttin': 3812,
#  'fone': 1723,
#  'place': 3590,
#  'key': 2533,
#  'window': 5401,
#  'soo': 4441,
#  'understand': 5096,
#  'ring': 4016,
#  'xxx': 5515,
#  'talent': 4736,
#  'town': 4979,
#  'mrt': 3087,
#  'finish': 1667,
#  'boy': 582,
#  'tour': 4977,
#  'vip': 5228,
#  'ticket': 4884,
#  'pre': 3699,
#  'club': 895,
#  'trackmarqu': 4985,
#  'ltd': 2787,
#  'info': 2326,
#  'vipclub': 5229,
#  'diet': 1228,
#  'slice': 4362,
#  'pizza': 3588,
#  'yesterday': 5552,
#  'wyli': 5500,
#  'tampa': 4744,
#  'sarasota': 4113,
#  'sent': 4200,
#  'jd': 2432,
#  'cum': 1077,
#  'execut': 1544,
#  'id': 2257,
#  'ryder': 4075,
#  'unsold': 5126,
#  'gibb': 1891,
#  'done': 1304,
#  'rayan': 3873,
#  'macleran': 2820,
#  'weird': 5336,
#  'bein': 456,
#  'woah': 5437,
#  'realis': 3889,
#  'actual': 51,
#  'signific': 4310,
#  'way': 5309,
#  'meant': 2916,
#  'jontin': 2468,
#  'earli': 1379,
#  'bird': 504,
#  'purchas': 3803,
#  'buzz': 680,
#  'goe': 1924,
#  'long': 2740,
#  'togeth': 4927,
#  'far': 1599,
#  'aww': 354,
#  'without': 5419,
#  'abj': 14,
#  'serv': 4210,
#  'stay': 4553,
#  'dad': 1102,
#  'alon': 145,
#  'moji': 3039,
#  'word': 5454,
#  'rich': 4008,
#  'fb': 1618,
#  'god': 1923,
#  'join': 2460,
#  'bear': 431,
#  'nick': 3215,
#  'tom': 4937,
#  'pete': 3542,
#  'dick': 1220,
#  'type': 5062,
#  'gay': 1852,
#  'upload': 5137,
#  'glad': 1905,
#  'walk': 5274,
#  'bedroom': 443,
#  'sed': 4176,
#  ...}

# %%
print("Total unique words:", len(vectorizer.vocabulary_))
print("Type of train_features:", type(train_features))
print("Shape of input data", train_features.shape)
# Out:
# Total unique words: 5597
# Type of train_features: <class 'scipy.sparse.csr.csr_matrix'>
# Shape of input data (4459, 5597)

# %% [markdown]
# ### 5. Model Building and Evaluation

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# %% [markdown]
# #### Logistic Regression

# %%
classifier = LogisticRegression()

# %%
dense_features = train_features.toarray()
dense_test = test_features.toarray()

fit = classifier.fit(dense_features,train['sms_spam'])
pred = fit.predict(dense_test)
accuracy = accuracy_score(pred,test['sms_spam'])
print('Accuracy of '+classifier.__class__.__name__+' is '+str(accuracy))
# Out:
# Accuracy of LogisticRegression is 0.9838565022421525

# %%
from sklearn import metrics
con_metric = metrics.confusion_matrix(pred,test['sms_spam'])
con_metric
# Out:
# array([[143,   0],
#        [ 18, 954]], dtype=int64)

# %%
# heatmap
sns.heatmap(con_metric, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.show()

# %%
#Checking Precision, Recall and F1 Score
print(metrics.classification_report(pred,test['sms_spam']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94       143
#            1       1.00      0.98      0.99       972
#
#     accuracy                           0.98      1115
#    macro avg       0.94      0.99      0.97      1115
# weighted avg       0.99      0.98      0.98      1115

# %% [markdown]
# #### Decision Tree

# %%
classifier_dt = DecisionTreeClassifier(max_depth = 2)

# %%
dense_features = train_features.toarray()
dense_test = test_features.toarray()

fit = classifier_dt.fit(dense_features,train['sms_spam'])
pred = fit.predict(dense_test)
accuracy = accuracy_score(pred,test['sms_spam'])
print('Accuracy of '+classifier.__class__.__name__+' is '+str(accuracy))
# Out:
# Accuracy of LogisticRegression is 0.9183856502242153

# %%
from sklearn import metrics
con_metric = metrics.confusion_matrix(pred,test['sms_spam'])
con_metric
# Out:
# array([[111,  41],
#        [ 50, 913]], dtype=int64)

# %%
# heatmap
sns.heatmap(con_metric, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.show()

# %%
#Checking Precision, Recall and F1 Score
print(metrics.classification_report(pred,test['sms_spam']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.73      0.71       152
#            1       0.96      0.95      0.95       963
#
#     accuracy                           0.92      1115
#    macro avg       0.82      0.84      0.83      1115
# weighted avg       0.92      0.92      0.92      1115

# %% [markdown]
# #### SVM

# %%
classifier_svc = SVC()

# %%
dense_features = train_features.toarray()
dense_test = test_features.toarray()

fit = classifier_svc.fit(dense_features,train['sms_spam'])
pred = fit.predict(dense_test)
accuracy = accuracy_score(pred,test['sms_spam'])
print('Accuracy of '+classifier.__class__.__name__+' is '+str(accuracy))
# Out:
# Accuracy of LogisticRegression is 0.9829596412556054

# %%
from sklearn import metrics
con_metric = metrics.confusion_matrix(pred,test['sms_spam'])
con_metric
# Out:
# array([[142,   0],
#        [ 19, 954]], dtype=int64)

# %%
# heatmap
sns.heatmap(con_metric, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.show()

# %%
#Checking Precision, Recall and F1 Score
print(metrics.classification_report(pred,test['sms_spam']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94       142
#            1       1.00      0.98      0.99       973
#
#     accuracy                           0.98      1115
#    macro avg       0.94      0.99      0.96      1115
# weighted avg       0.98      0.98      0.98      1115
